# %%
# !pip install colab_ssh --upgrade

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared
launch_ssh_cloudflared(password="octavio")
# Out:
# <style>
# *{
# 	outline:none;
# }
# code{
# 	display:inline-block;
# 	padding:5px 10px;
# 	background: #444;
# 	border-radius: 4px;
# 	white-space: pre-wrap;
# 	position:relative;
# 	color:white;
# }
# .copy-code-button{
# 	float:right;
# 	background:#333;
# 	color:white;
# 	border: none;
# 	margin: 0 0 0 10px;
# 	cursor: pointer;
# }
# p, li{
# 	max-width:700px;
# }
# .choices{
# 	display:flex;
# 	flex: 1 0 auto;
# }
# .choice-section{
# 	border:solid 1px #555;
# 	border-radius: 4px;
# 	min-width:300px;
# 	margin: 10px 15px 0 0;
# 	padding: 0 15px 15px 15px ;
# }
# .button{
# 	padding: 10px 15px;
# 	background:#333;
# 	border-radius: 4px;
# 	border:solid 1px #555;
# 	color:white;
# 	font-weight:bold;
# 	cursor:pointer;
# }
# .pill{
# 	padding:2px 4px;
# 	border-radius: 100px;
# 	background-color:#e65858;
# 	font-size:12px;
# 	font-weight:bold;
# 	margin: 0 15px;
# 	color:white;
# }
# </style>
# <details class="choice-section">
# 	<summary style="cursor:pointer">
# ...

# %% [markdown]
# ## Instructions
# 1. open vscode
# 1. click ctrl+shift+P
#     1. select Remote-SSH:Connect to Host...
# 1. enter the VSCode Remote SSH (from upper block)

# %% [markdown]
# The config file "C:\Users\octav\.ssh\config" is this one:

# %%
C:\Users\octav\.ssh\config <= WITHOUT THIS LINE
# Read more about SSH config files: https://linux.die.net/man/5/ssh_config
Host *.trycloudflare.com
    HostName %h
    User root
    Port 22
    ProxyCommand C:\\Users\\octav\\Documents\\version_control\\remote_colab\\cloudflared.exe access ssh --hostname %h

# %% [markdown]
# C:\ProgramData\ssh\ssh_config

# %%
# !ls /content/drive/MyDrive/Datasets/covid19/COVID-19-20/Train
# Out:
# checksum.md5				     license.txt
# COVID-19-20_TrainValidation.csv		     README.md
# COVID-19-20_TrainValidation.xlsx	     Train
# covid-segmentation.grand-challenge.org.gdoc  Validation

# %%
while True: pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b16dc615ea65> in <module>()
# ----> 1 while True: pass
#
# KeyboardInterrupt:

# %%
# Out:
# 1
